# %%
from get_data import get_data

from matplotlib import pyplot as plt
from scipy.signal import resample

from sklearn.feature_selection import mutual_info_classif

# %matplotlib inline

from fbcspModel import FBCSP_Model
from sklearn.model_selection import train_test_split

import numpy as np
import pandas as pd
# Out:
# /home/ubuntu/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## First Set Of Bands

# %%
Bands = [
        [[4,8],
        [8,12],
        [12,16],
        [16,20],
        [20,24],
        [24,28],
        [28,32],
        [32,36],
        [36,40],]
]

n_subject = 9

# %% [markdown]
# # without feature selection

# %%
accuracy_Without_Any_Selection = [[None for i in range(n_subject)] for i_band in range(len(Bands))]

# %%
kappa_Without_Any_Selection = [[] for i_band in range(len(Bands)) ]

# %%
for i_bands in range(len(Bands)):
    print("============================================================")
    print("for set Of bands : ",Bands[i_bands])
    
    model = FBCSP_Model(Output='power',
                        Path='../../../datasets/BNCI_IV_2A/',
                        OneVersuseOne= False,
                        selection=False,
                        Bands = Bands[i_bands])

    for i_subject in range(n_subject):
        model.subject = i_subject + 1
        model.load_data()
        accuracy_Without_Any_Selection[i_bands][i_subject] = model.run_csp()

    kappa_Without_Any_Selection[i_bands] = [ (accuracy_Without_Any_Selection[i_bands][i]-0.25)/0.75 for i in range(n_subject) ]
    accuracy_Without_Any_Selection[i_bands].append(np.mean(accuracy_Without_Any_Selection[i_bands]))
    kappa_Without_Any_Selection[i_bands].append(np.mean(kappa_Without_Any_Selection[i_bands]))
    Dataframe = pd.DataFrame({'kappa'    : kappa_Without_Any_Selection[i_bands] ,
                              'accuracy' : accuracy_Without_Any_Selection[i_bands] })
    last = Dataframe.index[-1]
    print(Dataframe.rename(index={last: 'averaged'}))
    
    print("***************************************************************")
# Out:
# ============================================================
# for set Of bands :  [[4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40]]
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.1854768588449607
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  2
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  2
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.16139759697256997
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  3
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  3
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.14657353394197456
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  4
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  4
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.16558557121377243
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  5
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  5
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.17464348457861636
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  6
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  6
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.16100935270619948
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  7
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  7
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.15957677149170144
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  8
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  8
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.18684950701864883
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 ,
# extracting feature and classification
# Time for one Evaluation 0.1728018829316804
#           accuracy     kappa
# 0         0.725979  0.634638
# 1         0.487633  0.316843
# 2         0.721612  0.628816
# 3         0.508772  0.345029
# 4         0.434783  0.246377
# 5         0.409302  0.212403
# 6         0.776173  0.701564
# 7         0.752768  0.670357
# 8         0.651515  0.535354
# averaged  0.607615  0.476820
# ***************************************************************

# %% [markdown]
# # flattening all

# %%
accuracy_Selection_Concatenation = [[None for i in range(n_subject)] for i_band in range(len(Bands))]

# %%
kappa_Selection_Concatenation = [[] for i_band in range(len(Bands)) ]

# %%
for i_bands in range(len(Bands)):
    print("============================================================")
    print("for set Of bands : ",Bands[i_bands])
    model = FBCSP_Model(Output='power',
                        Path='../../../datasets/BNCI_IV_2A/',
                    OneVersuseOne= False,
                    NO_selection = 16,
                    class_selection_base=False,
                    Bands = Bands[i_bands] )

    for i_subject in range(n_subject):
        model.subject = i_subject + 1
        model.load_data()
        accuracy_Selection_Concatenation[i_bands][i_subject] = model.run_csp()

    kappa_Selection_Concatenation[i_bands] = [ (accuracy_Selection_Concatenation[i_bands][i]-0.25)/0.75 for i in range(n_subject) ]
    accuracy_Selection_Concatenation[i_bands].append(np.mean(accuracy_Selection_Concatenation[i_bands]))
    kappa_Selection_Concatenation[i_bands].append(np.mean(kappa_Selection_Concatenation[i_bands]))
    Dataframe = pd.DataFrame({'kappa'    : kappa_Selection_Concatenation[i_bands] ,
                              'accuracy' : accuracy_Selection_Concatenation[i_bands] })
    last = Dataframe.index[-1]
    print(Dataframe.rename(index={last: 'averaged'}))
# Out:
# ============================================================
# for set Of bands :  [[4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40]]
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , [  2 137 118   5  19  28  82 109  55  38  64  73 104  47  37  22  58   4
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , [109  28   1 118 136  73  91 100  46  19  64  55  12 138 112   3   6  37
#   10  39 105 120  66  40  42 102 137  87 111  36 114 142 130  78 141   4
#  132  22  30   0 121  76  49  48 110 103  50   9 140  77  41  27 128  67
#  106 115  24   5   7  60  56  31  75 135 123  94 124 119  43 129  21 139
#   33  58  85  29  61  47   2  63  44  32  13 108  72 104 131  84   8  71
#  116  35  99 126  68  62  59 113  51 101  80 117  11  86  82  93  14  34
#   88  65 122  45 143  74 133 125  53  38  79  96  54  20  97  23  18  17
#   89 127 134  90  16  83  69  81  57  92  95  26 107  15  98  52  25  70]
# Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11300075801976052
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , [ 73 109 118   4 124 139 115  19 111  58  31 120 100 121  28 112  78   0
#   67  34   1  40  76  13 113  82  10 114  64  24  37  60   6 136  65  85
#   68  33  87  43  14 116  25 123  39  70 110  30 138   7 140   8  22  88
#  125 127  61  49 135 108  75 122 117 130 119  46  27  71  99  94  57 104
#  107  44  69 103  84   3  74  80  95 131  16 133 142  15 141 106 143  32
#   17 105  91  56  79  77  48  36  72  35 132  21   5  66   2  11  50  38
#   12  45  59 101  18  23  52  55 134  54 129  53  98  90  93  86  83  62
#   41  51  26  29 102 137 128  63  97  81 126  92  20   9  47  42  96  89]
# Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.1180274450417721
#           accuracy     kappa
# 0         0.697509  0.596679
# 1         0.466431  0.288575
# 2         0.736264  0.648352
# 3         0.491228  0.321637
# 4         0.413043  0.217391
# 5         0.376744  0.168992
# 6         0.768953  0.691937
# 7         0.678967  0.571956
# 8         0.617424  0.489899
# averaged  0.582952  0.443935

# %% [markdown]
# # class related

# %%
accuracy_Selection_Class = [[None for i in range(n_subject)] for i_band in range(len(Bands))]

kappa_Selection_Class = [[] for i_band in range(len(Bands)) ]

# %%
for i_bands in range(len(Bands)):
    print("============================================================")
    print("for set Of bands : ",Bands[i_bands])
    model = FBCSP_Model(Output='power',
                        Path='../../../datasets/BNCI_IV_2A/',
                        OneVersuseOne= False,
                        NO_selection = 4,
                        class_selection_base=True,
                        Bands = Bands[i_bands])

    for i_subject in range(n_subject):
        model.subject = i_subject + 1
        model.load_data()
        accuracy_Selection_Class[i_bands][i_subject] = model.run_csp()

    kappa_Selection_Class[i_bands] = [ (accuracy_Selection_Class[i_bands][i]-0.25)/0.75 for i in range(n_subject) ]
    accuracy_Selection_Class[i_bands].append(np.mean(accuracy_Selection_Class[i_bands]))
    kappa_Selection_Class[i_bands].append(np.mean(kappa_Selection_Class[i_bands]))
    Dataframe = pd.DataFrame({'kappa'    : kappa_Selection_Class[i_bands] ,
                              'accuracy' : accuracy_Selection_Class[i_bands] })
    last = Dataframe.index[-1]
    print(Dataframe.rename(index={last: 'averaged'}))
# Out:
# ============================================================
# for set Of bands :  [[4, 8], [8, 12], [12, 16], [16, 20], [20, 24], [24, 28], [28, 32], [32, 36], [36, 40]]
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  1
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11312340162827027
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  2
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  2
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11241958166600959
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  3
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  3
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.1146596718183804
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  4
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  4
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11722875268835771
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  5
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  5
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.1127822580544845
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  6
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  6
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11576652415963107
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  7
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  7
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.10803548351521956
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  8
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  8
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.11450736900977103
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# PATH :  ../../../datasets/BNCI_IV_2A/   subject :  9
# Calculate filter for band :
# 0 , 1 , 2 , 3 , 4 , 5 , 6 , 7 , 8 , Number of selected feature  32
#
# extracting feature and classification
# Time for one Evaluation 0.1199576249628356
#           accuracy     kappa
# 0         0.697509  0.596679
# 1         0.498233  0.330978
# 2         0.761905  0.682540
# 3         0.535088  0.380117
# 4         0.398551  0.198068
# 5         0.353488  0.137984
# 6         0.707581  0.610108
# 7         0.785978  0.714637
# 8         0.625000  0.500000
# averaged  0.595926  0.461234
